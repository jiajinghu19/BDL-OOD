# %%
# !git clone https://github.com/jiajinghu19/BDL-OOD.git

# %%
# %cd ./BDL-OOD/src/LMPBT/LMPBT_fork
# !ls
# Out:
# /kaggle/working/BDL-OOD/src/LMPBT/LMPBT_fork
# DCGAN_VAE_pixel.py	       __pycache__	     get_metrics.py
# FashionMNIST		       cel100_nll_vae.npy    get_torchvision_dataset.py
# FashionMNIST_eigenvalues.npy   cifar100_netE.pth     hessian3.py
# FashionMNIST_eigenvectors.npy  cifar100_netG.pth     svhn100_nll_vae.npy
# MNIST			       cifar100_nll_vae.npy  train_vae.py
# README.md		       get_eig_vecs_vae.py   utils.py
# Readme.txt		       get_lmpbt_score.py

# %%
# !python get_eig_vecs_vae.py --nc 1 --training_dataset FashionMNIST --state_E ../results/Train_FashionMNIST/FashionMNIST_epoch499_netE.pth --state_G ../results/Train_FashionMNIST/FashionMNIST_epoch499_netG.pth --eigenvalues FashionMNIST_eigenvalues.npy --eigenvectors FashionMNIST_eigenvectors.npy

# %%
# !python get_lmpbt_score.py --nc 1 --in_distro_dataset FashionMNIST --out_distro_dataset MNIST --state_E ../results/Train_FashionMNIST/FashionMNIST_epoch499_netE.pth --state_G ../results/Train_FashionMNIST/FashionMNIST_epoch499_netG.pth --eigenvalues FashionMNIST_eigenvalues.npy --eigenvectors FashionMNIST_eigenvectors.npy
# Out:
# Building models...
# Building complete...
# get_lmpbt_score.py:131: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   time_start = time.clock()
# get_lmpbt_score.py:175: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   time_elapsed = (time.clock() - time_start)

# %%
# !python get_metrics.py
# Out:
# AUROC: 0.8722522429931329 AUPR: 0.9140693775311266 FPR80: 0.18827639751552794
