# %%
# !git clone https://github.com/jiajinghu19/BDL-OOD.git

# %%
# %cd ./BDL-OOD/src/LMPBT/LMPBT_fork
# !ls

# %%
# !python get_eig_vecs_vae.py --training_dataset MNIST --state_E ../results/Train_MNIST/MNIST_epoch498_netE.pth --state_G ../results/Train_MNIST/MNIST_epoch498_netG.pth --eigenvalues MNIST_eigenvalues.npy --eigenvectors MNIST_eigenvectors.npy
# Out:
# ^C
# Traceback (most recent call last):
#   File "get_eig_vecs_vae.py", line 4, in <module>
#     import torch
#   File "/opt/conda/lib/python3.7/site-packages/torch/__init__.py", line 794, in <module>
#     import torch.nn.quantizable
#   File "/opt/conda/lib/python3.7/site-packages/torch/nn/quantizable/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/opt/conda/lib/python3.7/site-packages/torch/nn/quantizable/modules/__init__.py", line 2, in <module>
#     from .rnn import LSTM
#   File "/opt/conda/lib/python3.7/site-packages/torch/nn/quantizable/modules/rnn.py", line 244, in <module>
#     class LSTM(torch.nn.Module):
#   File "/opt/conda/lib/python3.7/site-packages/torch/nn/quantizable/modules/rnn.py", line 314, in LSTM
#     def forward(self, x: Tensor, hidden: Optional[Tuple[Tensor, Tensor]] = None):
#   File "/opt/conda/lib/python3.7/typing.py", line 749, in __getitem__
#     def __getitem__(self, params):
# KeyboardInterrupt

# %%
# !python get_lmpbt_score.py --in_distro_dataset MNIST --out_distro_dataset FashionMNIST --state_E ../results/Train_MNIST/MNIST_epoch498_netE.pth --state_G ../results/Train_MNIST/MNIST_epoch498_netG.pth --eigenvalues MNIST_eigenvalues.npy --eigenvectors MNIST_eigenvectors.npy
# Out:
# ^C
# Traceback (most recent call last):
#   File "get_lmpbt_score.py", line 4, in <module>
#     import torch
#   File "/opt/conda/lib/python3.7/site-packages/torch/__init__.py", line 199, in <module>
#     from torch._C import *  # noqa: F403
# RuntimeError: KeyboardInterrupt:

# %%
# !python get_metrics.py
