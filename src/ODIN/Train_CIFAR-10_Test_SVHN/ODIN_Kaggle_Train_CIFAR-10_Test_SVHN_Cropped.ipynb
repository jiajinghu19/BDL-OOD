# %% [markdown]
# # ODIN Kaggle - Train on CIFAR-10 and Test on SVHN Cropped
#
# This notebook is set up to run on Kaggle since they have free GPU hours. At a high level, this notebook
# - Clones my (Harry's) forked repo of ODIN since their code has some bugs in Python 3 (I'm assuming their syntax was valid in Python 2 or something)
# - Downloads their DenseNet-BC trained on CIFAR-10
# - Downloads SVHN cropped test set
# - Evaluates the model using ODIN and using the baseline

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# Running cells with 'Python 3.7.2 64-bit ('3.7.2')' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/harryli/.pyenv/versions/3.7.2/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
# !git clone https://github.com/harryli0088/odin
# Out:
# Cloning into 'odin'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 41 (delta 10), reused 32 (delta 10), pack-reused 0
# Unpacking objects: 100% (41/41), 486.16 KiB | 6.85 MiB/s, done.

# %%
# download dense net model
# %cd /kaggle/working/odin/models
# !wget https://www.dropbox.com/s/wr4kjintq1tmorr/densenet10.pth.tar.gz
# Out:
# /kaggle/working/odin/models
# --2022-11-15 02:33:10--  https://www.dropbox.com/s/wr4kjintq1tmorr/densenet10.pth.tar.gz
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.9.18, 2620:100:601f:18::a27d:912
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.9.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/wr4kjintq1tmorr/densenet10.pth.tar.gz [following]
# --2022-11-15 02:33:10--  https://www.dropbox.com/s/raw/wr4kjintq1tmorr/densenet10.pth.tar.gz
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc6e6c60dde3ef38fae373c89199.dl.dropboxusercontent.com/cd/0/inline/BwxgPIjJnZXszf_FFgLV_9ZlCaLbmJquCR-PIULt4ivhqRKNRpowTl-npGiVYSK1o2Xe7GBBfK_f0CATKZNunso_Rf8PEpVgUUBqxCGB37uesq0ffrNItutmBVDY4JC_jx6XhYWUsw9c0eaxX8cJrJg09sJWio77cA6AbbNnDCELwg/file# [following]
# --2022-11-15 02:33:11--  https://uc6e6c60dde3ef38fae373c89199.dl.dropboxusercontent.com/cd/0/inline/BwxgPIjJnZXszf_FFgLV_9ZlCaLbmJquCR-PIULt4ivhqRKNRpowTl-npGiVYSK1o2Xe7GBBfK_f0CATKZNunso_Rf8PEpVgUUBqxCGB37uesq0ffrNItutmBVDY4JC_jx6XhYWUsw9c0eaxX8cJrJg09sJWio77cA6AbbNnDCELwg/file
# Resolving uc6e6c60dde3ef38fae373c89199.dl.dropboxusercontent.com (uc6e6c60dde3ef38fae373c89199.dl.dropboxusercontent.com)... 162.125.9.15, 2620:100:601f:15::a27d:90f
# Connecting to uc6e6c60dde3ef38fae373c89199.dl.dropboxusercontent.com (uc6e6c60dde3ef38fae373c89199.dl.dropboxusercontent.com)|162.125.9.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Bww6UHmWgoo_4y7YtpB-tlYqBBIE85hMJDfcZAyglA1wLwjHTp1bu6M-tb1YHFtnSkOMgu4mL0OppobXMUB4G-icq14mMPvhTPNyX47u2FFfx2rUnC7QqxNzQ6ks8RUPofU1FpTtMvaedmH51hzMflgqoiqjaTbgOgfMg_tcIayC1JJ4owxgJnhTSkTljlAuyzpY7uWMgBtm7raiCFAjlgL5qYxmupaqWsN9Ufq_utL5CIDfuLjRQIFrxRct5PuizsyHmMg0d55RMuPXLyinPtM_3CDjTmp_blv9ZxU7cSvPUyv2cciY7g3XXHCpc565rQu6HinAoWGL08yuX-EAw_j4Wb0ZWT_p0RcaH4rKF5K5Nse24W_buwOA1bbUJhhC_iMxHhFhoopybLIpUBfILcsCi7iQ26PhjZWd6YsnjVpimA/file [following]
# --2022-11-15 02:33:11--  https://uc6e6c60dde3ef38fae373c89199.dl.dropboxusercontent.com/cd/0/inline2/Bww6UHmWgoo_4y7YtpB-tlYqBBIE85hMJDfcZAyglA1wLwjHTp1bu6M-tb1YHFtnSkOMgu4mL0OppobXMUB4G-icq14mMPvhTPNyX47u2FFfx2rUnC7QqxNzQ6ks8RUPofU1FpTtMvaedmH51hzMflgqoiqjaTbgOgfMg_tcIayC1JJ4owxgJnhTSkTljlAuyzpY7uWMgBtm7raiCFAjlgL5qYxmupaqWsN9Ufq_utL5CIDfuLjRQIFrxRct5PuizsyHmMg0d55RMuPXLyinPtM_3CDjTmp_blv9ZxU7cSvPUyv2cciY7g3XXHCpc565rQu6HinAoWGL08yuX-EAw_j4Wb0ZWT_p0RcaH4rKF5K5Nse24W_buwOA1bbUJhhC_iMxHhFhoopybLIpUBfILcsCi7iQ26PhjZWd6YsnjVpimA/file
# Reusing existing connection to uc6e6c60dde3ef38fae373c89199.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3023135 (2.9M) [application/octet-stream]
# Saving to: ‘densenet10.pth.tar.gz’
#
# densenet10.pth.tar. 100%[===================>]   2.88M  --.-KB/s    in 0.08s
#
# 2022-11-15 02:33:12 (37.8 MB/s) - ‘densenet10.pth.tar.gz’ saved [3023135/3023135]

# %%
# %cd /kaggle/working/odin/models
# !tar -xf densenet10.pth.tar.gz
# !ls
# Out:
# /kaggle/working/odin/models
# densenet10.pth	densenet10.pth.tar.gz

# %%
# download SVHN cropped test images
# !mkdir /kaggle/working/odin/data
# !mkdir /kaggle/working/odin/data/SVHN_Cropped
# !mkdir /kaggle/working/odin/data/SVHN_Cropped/test
# %cd /kaggle/working/odin/data
# !wget http://ufldl.stanford.edu/housenumbers/test_32x32.mat
# !ls
# Out:
# /kaggle/working/odin/data
# --2022-11-15 02:33:25--  http://ufldl.stanford.edu/housenumbers/test_32x32.mat
# Resolving ufldl.stanford.edu (ufldl.stanford.edu)... 171.64.68.10
# Connecting to ufldl.stanford.edu (ufldl.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64275384 (61M) [text/plain]
# Saving to: ‘test_32x32.mat’
#
# test_32x32.mat      100%[===================>]  61.30M  16.9MB/s    in 3.6s
#
# 2022-11-15 02:33:29 (16.9 MB/s) - ‘test_32x32.mat’ saved [64275384/64275384]
#
# SVHN_Cropped  test_32x32.mat

# %%
# unpack SVHN images
from scipy.io import loadmat
import matplotlib.pyplot as plt

svhn = dict()
loadmat('./test_32x32.mat', mdict=svhn)
num_images = svhn["X"].shape[3]
print("num_images",num_images)
for i in range(num_images):
    plt.imsave("./SVHN_Cropped/test/{}.png".format(i),svhn["X"][:,:,:,i])
    # plt.imshow(svhn["X"][:,:,:,0])
    # plt.show()
# Out:
# num_images 26032

# %%
#verify SVHN test images were downloaded
# !ls -U SVHN_Cropped/test | head -5
# Out:
# 8933.png
# 13242.png
# 17356.png
# 2115.png
# 16866.png
# ls: write error: Broken pipe

# %%
# %cd /kaggle/working/odin/code
# from the ODIN README:
# model: DenseNet-BC, in-distribution: CIFAR-10, out-distribution: TinyImageNet (crop)
# magnitude: 0.0014, temperature 1000, gpu: 0
# !python main.py --nn densenet10 --out_dataset SVHN_Cropped --magnitude 0.0014 --temperature 1000 --gpu 0
# Out:
# /kaggle/working/odin/code
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py:786: SourceChangeWarning: source code of class 'torch.nn.modules.conv.Conv2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py:786: SourceChangeWarning: source code of class 'torch.nn.modules.container.Sequential' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py:786: SourceChangeWarning: source code of class 'torch.nn.modules.batchnorm.BatchNorm2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py:786: SourceChangeWarning: source code of class 'torch.nn.modules.activation.ReLU' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py:786: SourceChangeWarning: source code of class 'torch.nn.modules.linear.Linear' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ../data/cifar-10-python.tar.gz
# 170499072it [00:02, 76332282.20it/s]
# Extracting ../data/cifar-10-python.tar.gz to ../data
# /kaggle/working/odin/code/calData.py:73: UserWarning: This overload of add is deprecated:
# 	add(Tensor input, Number alpha, Tensor other, *, Tensor out)
# Consider using one of the following signatures instead:
# 	add(Tensor input, Tensor other, *, Number alpha, Tensor out) (Triggered internally at  /usr/local/src/pytorch/torch/csrc/utils/python_arg_parser.cpp:1055.)
#   tempInputs = torch.add(inputs.data,  -noiseMagnitude1, gradient)
#  100/9000 images processed, 14.6 seconds used.
#  200/9000 images processed, 5.4 seconds used.
#  300/9000 images processed, 5.2 seconds used.
#  400/9000 images processed, 5.6 seconds used.
#  500/9000 images processed, 5.1 seconds used.
#  600/9000 images processed, 5.4 seconds used.
#  700/9000 images processed, 5.7 seconds used.
#  800/9000 images processed, 5.5 seconds used.
#  900/9000 images processed, 5.2 seconds used.
# 1000/9000 images processed, 5.4 seconds used.
# 1100/9000 images processed, 5.3 seconds used.
# 1200/9000 images processed, 5.4 seconds used.
# 1300/9000 images processed, 5.7 seconds used.
# 1400/9000 images processed, 5.4 seconds used.
# 1500/9000 images processed, 5.1 seconds used.
# 1600/9000 images processed, 5.4 seconds used.
# 1700/9000 images processed, 5.3 seconds used.
# 1800/9000 images processed, 5.2 seconds used.
# 1900/9000 images processed, 5.9 seconds used.
# 2000/9000 images processed, 5.1 seconds used.
# 2100/9000 images processed, 5.2 seconds used.
# 2200/9000 images processed, 5.1 seconds used.
# 2300/9000 images processed, 5.3 seconds used.
# 2400/9000 images processed, 5.2 seconds used.
# 2500/9000 images processed, 6.0 seconds used.
# 2600/9000 images processed, 5.2 seconds used.
# 2700/9000 images processed, 5.4 seconds used.
# 2800/9000 images processed, 5.1 seconds used.
# 2900/9000 images processed, 5.4 seconds used.
# 3000/9000 images processed, 5.3 seconds used.
# 3100/9000 images processed, 5.9 seconds used.
# 3200/9000 images processed, 4.9 seconds used.
# 3300/9000 images processed, 5.3 seconds used.
# 3400/9000 images processed, 5.0 seconds used.
# 3500/9000 images processed, 5.2 seconds used.
# 3600/9000 images processed, 5.0 seconds used.
# 3700/9000 images processed, 5.8 seconds used.
# 3800/9000 images processed, 4.9 seconds used.
# 3900/9000 images processed, 5.2 seconds used.
# 4000/9000 images processed, 5.0 seconds used.
# 4100/9000 images processed, 5.4 seconds used.
# 4200/9000 images processed, 5.1 seconds used.
# 4300/9000 images processed, 5.8 seconds used.
# 4400/9000 images processed, 5.0 seconds used.
# 4500/9000 images processed, 5.0 seconds used.
# 4600/9000 images processed, 5.3 seconds used.
# 4700/9000 images processed, 5.1 seconds used.
# 4800/9000 images processed, 5.3 seconds used.
# 4900/9000 images processed, 5.7 seconds used.
# 5000/9000 images processed, 5.3 seconds used.
# 5100/9000 images processed, 5.0 seconds used.
# 5200/9000 images processed, 5.3 seconds used.
# 5300/9000 images processed, 5.2 seconds used.
# 5400/9000 images processed, 5.5 seconds used.
# 5500/9000 images processed, 5.4 seconds used.
# 5600/9000 images processed, 5.3 seconds used.
# 5700/9000 images processed, 4.9 seconds used.
# 5800/9000 images processed, 5.3 seconds used.
# 5900/9000 images processed, 5.0 seconds used.
# 6000/9000 images processed, 5.2 seconds used.
# 6100/9000 images processed, 5.5 seconds used.
# 6200/9000 images processed, 5.2 seconds used.
# 6300/9000 images processed, 5.0 seconds used.
# 6400/9000 images processed, 5.2 seconds used.
# 6500/9000 images processed, 5.2 seconds used.
# 6600/9000 images processed, 5.0 seconds used.
# 6700/9000 images processed, 5.8 seconds used.
# 6800/9000 images processed, 4.9 seconds used.
# 6900/9000 images processed, 5.2 seconds used.
# 7000/9000 images processed, 5.0 seconds used.
# 7100/9000 images processed, 5.3 seconds used.
# 7200/9000 images processed, 5.2 seconds used.
# 7300/9000 images processed, 5.8 seconds used.
# 7400/9000 images processed, 5.1 seconds used.
# 7500/9000 images processed, 5.4 seconds used.
# 7600/9000 images processed, 5.3 seconds used.
# 7700/9000 images processed, 5.6 seconds used.
# 7800/9000 images processed, 5.5 seconds used.
# 7900/9000 images processed, 5.5 seconds used.
# 8000/9000 images processed, 5.0 seconds used.
# 8100/9000 images processed, 5.2 seconds used.
# 8200/9000 images processed, 5.0 seconds used.
# 8300/9000 images processed, 5.3 seconds used.
# 8400/9000 images processed, 5.5 seconds used.
# 8500/9000 images processed, 5.4 seconds used.
# 8600/9000 images processed, 5.1 seconds used.
# 8700/9000 images processed, 5.5 seconds used.
# 8800/9000 images processed, 5.2 seconds used.
# 8900/9000 images processed, 5.4 seconds used.
# 9000/9000 images processed, 5.5 seconds used.
# Processing out-of-distribution images
#  100/9000 images processed, 7.8 seconds used.
#  200/9000 images processed, 4.9 seconds used.
#  300/9000 images processed, 5.3 seconds used.
#  400/9000 images processed, 5.0 seconds used.
#  500/9000 images processed, 5.3 seconds used.
#  600/9000 images processed, 5.5 seconds used.
#  700/9000 images processed, 5.4 seconds used.
#  800/9000 images processed, 5.2 seconds used.
#  900/9000 images processed, 5.4 seconds used.
# 1000/9000 images processed, 5.0 seconds used.
# 1100/9000 images processed, 5.2 seconds used.
# 1200/9000 images processed, 5.7 seconds used.
# 1300/9000 images processed, 5.3 seconds used.
# 1400/9000 images processed, 5.2 seconds used.
# 1500/9000 images processed, 5.2 seconds used.
# 1600/9000 images processed, 5.4 seconds used.
# 1700/9000 images processed, 5.0 seconds used.
# 1800/9000 images processed, 6.0 seconds used.
# 1900/9000 images processed, 5.2 seconds used.
# 2000/9000 images processed, 5.5 seconds used.
# 2100/9000 images processed, 5.2 seconds used.
# 2200/9000 images processed, 5.4 seconds used.
# 2300/9000 images processed, 5.1 seconds used.
# 2400/9000 images processed, 5.9 seconds used.
# 2500/9000 images processed, 5.0 seconds used.
# 2600/9000 images processed, 5.4 seconds used.
# 2700/9000 images processed, 5.1 seconds used.
# 2800/9000 images processed, 5.2 seconds used.
# 2900/9000 images processed, 5.4 seconds used.
# 3000/9000 images processed, 5.8 seconds used.
# 3100/9000 images processed, 5.1 seconds used.
# 3200/9000 images processed, 5.4 seconds used.
# 3300/9000 images processed, 5.1 seconds used.
# 3400/9000 images processed, 5.5 seconds used.
# 3500/9000 images processed, 5.6 seconds used.
# 3600/9000 images processed, 5.4 seconds used.
# 3700/9000 images processed, 5.2 seconds used.
# 3800/9000 images processed, 5.5 seconds used.
# 3900/9000 images processed, 5.2 seconds used.
# 4000/9000 images processed, 5.5 seconds used.
# 4100/9000 images processed, 5.8 seconds used.
# 4200/9000 images processed, 5.4 seconds used.
# 4300/9000 images processed, 5.2 seconds used.
# 4400/9000 images processed, 5.5 seconds used.
# 4500/9000 images processed, 5.2 seconds used.
# 4600/9000 images processed, 5.4 seconds used.
# 4700/9000 images processed, 5.5 seconds used.
# 4800/9000 images processed, 5.3 seconds used.
# 4900/9000 images processed, 5.1 seconds used.
# 5000/9000 images processed, 5.3 seconds used.
# 5100/9000 images processed, 5.2 seconds used.
# 5200/9000 images processed, 5.1 seconds used.
# 5300/9000 images processed, 6.0 seconds used.
# 5400/9000 images processed, 5.2 seconds used.
# 5500/9000 images processed, 5.4 seconds used.
# 5600/9000 images processed, 5.2 seconds used.
# 5700/9000 images processed, 5.4 seconds used.
# 5800/9000 images processed, 5.1 seconds used.
# 5900/9000 images processed, 5.9 seconds used.
# 6000/9000 images processed, 5.0 seconds used.
# 6100/9000 images processed, 5.4 seconds used.
# 6200/9000 images processed, 5.0 seconds used.
# 6300/9000 images processed, 5.3 seconds used.
# 6400/9000 images processed, 5.1 seconds used.
# 6500/9000 images processed, 5.8 seconds used.
# 6600/9000 images processed, 5.1 seconds used.
# 6700/9000 images processed, 5.4 seconds used.
# 6800/9000 images processed, 5.1 seconds used.
# 6900/9000 images processed, 5.4 seconds used.
# 7000/9000 images processed, 5.1 seconds used.
# 7100/9000 images processed, 5.9 seconds used.
# 7200/9000 images processed, 5.2 seconds used.
# 7300/9000 images processed, 5.6 seconds used.
# 7400/9000 images processed, 5.3 seconds used.
# 7500/9000 images processed, 5.5 seconds used.
# 7600/9000 images processed, 5.6 seconds used.
# 7700/9000 images processed, 5.4 seconds used.
# 7800/9000 images processed, 5.1 seconds used.
# 7900/9000 images processed, 5.4 seconds used.
# 8000/9000 images processed, 5.1 seconds used.
# 8100/9000 images processed, 5.3 seconds used.
# 8200/9000 images processed, 5.6 seconds used.
# 8300/9000 images processed, 5.4 seconds used.
# 8400/9000 images processed, 5.1 seconds used.
# 8500/9000 images processed, 5.3 seconds used.
# 8600/9000 images processed, 5.4 seconds used.
# 8700/9000 images processed, 5.2 seconds used.
# 8800/9000 images processed, 5.9 seconds used.
# 8900/9000 images processed, 5.2 seconds used.
# 9000/9000 images processed, 5.5 seconds used.
# Neural network architecture:          DenseNet-BC-100
# In-distribution dataset:                     CIFAR-10
# Out-of-distribution dataset:             SVHN_Cropped
#
#                           Baseline         Our Method
# FPR at TPR 95%:              60.5%              51.3%
# Detection error:             17.0%              18.4%
# AUROC:                       89.9%              89.7%
# AUPR In:                     90.6%              90.8%
# AUPR Out:                    86.8%              88.8%
