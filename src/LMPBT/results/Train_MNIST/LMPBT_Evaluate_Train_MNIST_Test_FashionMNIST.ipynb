# %%
# !git clone https://github.com/jiajinghu19/BDL-OOD.git

# %%
# %cd ./BDL-OOD/src/LMPBT/LMPBT_fork
# !ls

# %%
# !python get_eig_vecs_vae.py --nc 1 --training_dataset MNIST --state_E ../results/Train_MNIST/MNIST_epoch498_netE.pth --state_G ../results/Train_MNIST/MNIST_epoch498_netG.pth --eigenvalues MNIST_eigenvalues.npy --eigenvectors MNIST_eigenvectors.npy

# %%
# !python get_lmpbt_score.py --in_distro_dataset MNIST --out_distro_dataset FashionMNIST --state_E ../results/Train_MNIST/MNIST_epoch498_netE.pth --state_G ../results/Train_MNIST/MNIST_epoch498_netG.pth --eigenvalues MNIST_eigenvalues.npy --nc 1 --eigenvectors MNIST_eigenvectors.npy

# %%
# !python get_metrics.py
