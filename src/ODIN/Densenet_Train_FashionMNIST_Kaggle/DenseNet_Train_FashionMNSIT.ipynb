# %% [markdown]
# # Train Densenet on Fashion MNIST

# %%
# !git clone https://github.com/jiajinghu19/BDL-OOD.git
# Out:
# Cloning into 'BDL-OOD'...
# remote: Enumerating objects: 263, done.
# remote: Counting objects: 100% (263/263), done.
# remote: Compressing objects: 100% (188/188), done.
# remote: Total 263 (delta 112), reused 211 (delta 64), pack-reused 0
# Receiving objects: 100% (263/263), 33.03 MiB | 30.94 MiB/s, done.
# Resolving deltas: 100% (112/112), done.

# %%
# %cd ./BDL-OOD/src/densenet.pytorch_fork
# !mkdir output
# !ls
# Out:
# /kaggle/working/BDL-OOD/src/densenet.pytorch_fork
# LICENSE			       densenet.py			output
# README.md		       images				plot.py
# attic			       load_model_playground_script.py	train.py
# compute_dataset_means_stds.py  make_graph.py

# %%
# !python train.py --dataset FashionMNIST --save output --opt adam
# Out:
# ...
# 26422272it [00:01, 16318744.42it/s]
# Extracting FashionMNIST/FashionMNIST/raw/train-images-idx3-ubyte.gz to FashionMNIST/FashionMNIST/raw
#
# ...
# 29696it [00:00, 292577.51it/s]
# Extracting FashionMNIST/FashionMNIST/raw/train-labels-idx1-ubyte.gz to FashionMNIST/FashionMNIST/raw
#
# ...
# 4422656it [00:00, 5462947.82it/s]
# Extracting FashionMNIST/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to FashionMNIST/FashionMNIST/raw
#
# ...
# 6144it [00:00, 18250569.25it/s]
# Extracting FashionMNIST/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to FashionMNIST/FashionMNIST/raw
#
#   + Number of params: 768730
# /kaggle/working/BDL-OOD/src/densenet.pytorch_fork/densenet.py:115: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   out = F.log_softmax(self.fc(out))
# Train Epoch: 0.00 [64/60000 (0%)]	Loss: 2.330483	Error: 92.187500
# Train Epoch: 0.05 [3072/60000 (5%)]	Loss: 1.123582	Error: 39.062500
# ...
